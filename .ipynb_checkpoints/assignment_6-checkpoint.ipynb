# %% [markdown]
# # Assignment 6
# ### Do Question 6, and three more questions of your choice.

# %% [markdown]
# ### 1. Set review:
#
# - Operations on sets (hints: sketch venn-type diagrams, and showing $A=B$ is the same as $A \subseteq B$ and $B \subseteq A$):
# - $ (A \backslash B) \cup (A \cap B) = A $
# - $ A \cup ( B \cap C) = (A \cup B) \cap (A \cup C)$
# - $ A \backslash (B \cup C) = A\backslash B \cap A \backslash C $ and $A \backslash (B \cap C) = A \backslash B \cup A \backslash C$
#
# - Plot the following sets:
#     - $A = \{x \in \mathbb{R}: x^2 -1 \ge 0 \}$
#     - $B = \{ (x,y) \in \mathbb{R}^2: 3x -2y \ge 0 \}$
#     - $C = \{ (x,y) \in \mathbb{R}^2: xy \ge 3 \}$
#     - $D = \{ (x_1,x_2) \in \mathbb{R}^2: x_1 \ge 0, x_2 \ge 0, x_1 + x_2 \le 1 \}$
# - The power set of $A$ is the set of all subsets of $A$, denoted $\mathcal{P}(A)$. What is the power set of $\{ 1, 2, 3 \}$? (Hint: The empty set is a subset of every set; the whole set is a subset of itself.)

# %% [markdown]
# ### 2. Probability space basics:
#
# - What are the outcomes for rolling a single, fair **THREE**-sided die? What's the set of all events? What are the probabilities of all the events?
# - What are the outcomes for rolling a fair **THREE**-sided die? What's the set of all events? What are the probabilities of all the events?
# - What about flipping a fair coin twice? (Hint: There are 4 outcomes, and $2^{4} = 16$ events.)
# - What about rolling the **THREE**-sided die twice, and adding the results? Don't write down the set of all the possible events, but describe briefly what it looks like and how large it is. (Hint: There are 5 outcomes, and $2^{5}=32$ possible events.)
#
# Obviously, a "three-sided die" doesn't exist, but this keeps you from spending a lot of time suffering in working out sets of events.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from math import sqrt

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %%
print("Three-sided Die (Single Roll):")
print("Outcomes: {1, 2, 3}")
print("Set of all events (power set): 2^3 = 8 events")
print("Events: ∅, {1}, {2}, {3}, {1,2}, {1,3}, {2,3}, {1,2,3}")

print("\nProbabilities:")
print("P(∅) = 0")
print("P({1}) = 1/3")
print("P({2}) = 1/3") 
print("P({3}) = 1/3")
print("P({1,2}) = 2/3")
print("P({1,3}) = 2/3")
print("P({2,3}) = 2/3")
print("P({1,2,3}) = 1")
# Out:
# Three-sided Die (Single Roll):
# Outcomes: {1, 2, 3}
# Set of all events (power set): 2^3 = 8 events
# Events: ∅, {1}, {2}, {3}, {1,2}, {1,3}, {2,3}, {1,2,3}
#
# Probabilities:
# P(∅) = 0
# P({1}) = 1/3
# P({2}) = 1/3
# P({3}) = 1/3
# P({1,2}) = 2/3
# P({1,3}) = 2/3
# P({2,3}) = 2/3
# P({1,2,3}) = 1

# %%
outcomes_coin = ['HH', 'HT', 'TH', 'TT']
print(f"Outcomes: {outcomes_coin}")
print("Number of events: 2^4 = 16")
print("Each outcome has probability: 1/4 = 0.25")

np.random.seed(42)
coin_flips = np.random.choice(['H', 'T'], size=(10000, 2))
coin_results = [''.join(flip) for flip in coin_flips]
coin_counts = Counter(coin_results)

print("\nSimulated probabilities (n=10000):")
for outcome in outcomes_coin:
    prob = coin_counts[outcome] / 10000
    print(f"P({outcome}) = {prob:.3f}")
# Out:
# Outcomes: ['HH', 'HT', 'TH', 'TT']
# Number of events: 2^4 = 16
# Each outcome has probability: 1/4 = 0.25
#
# Simulated probabilities (n=10000):
# P(HH) = 0.248
# P(HT) = 0.252
# P(TH) = 0.254
# P(TT) = 0.246

# %%
print("Possible sums: {2, 3, 4, 5, 6}")
print("Number of events: 2^5 = 32")
print("The set of all events is the power set of the 5 possible sum outcomes")

print("\nTheoretical probabilities:")
print("Sum 2: (1,1) -> 1/9")
print("Sum 3: (1,2), (2,1) -> 2/9") 
print("Sum 4: (1,3), (2,2), (3,1) -> 3/9")
print("Sum 5: (2,3), (3,2) -> 2/9")
print("Sum 6: (3,3) -> 1/9")

np.random.seed(42)
die_rolls = np.random.choice([1, 2, 3], size=(10000, 2))
sums = np.sum(die_rolls, axis=1)
sum_counts = Counter(sums)

print("\nSimulated probabilities (n=10000):")
for s in range(2, 7):
    prob = sum_counts[s] / 10000
    theoretical = {2: 1/9, 3: 2/9, 4: 3/9, 5: 2/9, 6: 1/9}[s]
    print(f"P(sum={s}) = {prob:.3f} (theoretical: {theoretical:.3f})")
# Out:
# Possible sums: {2, 3, 4, 5, 6}
# Number of events: 2^5 = 32
# The set of all events is the power set of the 5 possible sum outcomes
#
# Theoretical probabilities:
# Sum 2: (1,1) -> 1/9
# Sum 3: (1,2), (2,1) -> 2/9
# Sum 4: (1,3), (2,2), (3,1) -> 3/9
# Sum 5: (2,3), (3,2) -> 2/9
# Sum 6: (3,3) -> 1/9
#
# Simulated probabilities (n=10000):
# P(sum=2) = 0.113 (theoretical: 0.111)
# P(sum=3) = 0.223 (theoretical: 0.222)
# P(sum=4) = 0.338 (theoretical: 0.333)
# P(sum=5) = 0.217 (theoretical: 0.222)
# P(sum=6) = 0.109 (theoretical: 0.111)

# %% [markdown]
# ### 3. Random Variable Basics
#
# - Imagine rolling a fair single six-sided die. There are 6 outcomes, all equally likely. Derive the sample space and the space of events. What are the probabilities of the outcomes and events?
# - Consider a random variable that assigns the square root of the number of pips on the die to each outcome. Write code to simulate rolling a single six-sided die and computing the value of the random variable. Simulate 5000 rolls and plot the mass function and ECDF of the random variable.
# - Imagine rolling two fair six-sided die. Consider a random variable that adds up the pips on the dice. There are 11 outcomes (2 , 3, ..., 12), but not all are equally likely. Derive the sample space and **describe** the space of events. What are the probabilities of the outcomes?
# - Write code to simulate the random variable (rolling two six-sided die and adding the results together). Simulate 10000 rolls and plot the mass function and ECDF.

# %%
import numpy as np
import matplotlib.pyplot as plt

n1 = 5000
rolls1 = np.random.randint(1, 7, size=n1)
X = np.sqrt(rolls1)

unique_vals, counts = np.unique(X, return_counts=True)
pmf = counts / n1

plt.figure()
plt.bar(unique_vals, pmf)
plt.title("PMF of X = sqrt(single die)")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()

x_sorted = np.sort(X)
ecdf = np.arange(1, n1 + 1) / n1

plt.figure()
plt.step(x_sorted, ecdf, where="post")
plt.title("ECDF of X = sqrt(single die)")
plt.xlabel("Value")
plt.ylabel("ECDF")
plt.show()

n2 = 10000
die1 = np.random.randint(1, 7, size=n2)
die2 = np.random.randint(1, 7, size=n2)
Y = die1 + die2

unique_sums, counts_sums = np.unique(Y, return_counts=True)
pmf_sums = counts_sums / n2

plt.figure()
plt.bar(unique_sums, pmf_sums)
plt.title("PMF of Y = sum(two dice)")
plt.xlabel("Sum of two dice")
plt.ylabel("Probability")
plt.xticks(unique_sums)
plt.show()

y_sorted = np.sort(Y)
ecdf2 = np.arange(1, n2 + 1) / n2

plt.figure()
plt.step(y_sorted, ecdf2, where="post")
plt.title("ECDF of Y = sum(two dice)")
plt.xlabel("Sum of two dice")
plt.ylabel("ECDF")
plt.show()

# %% [markdown]
# ### 4. Roulette
#
# This question will be easiest if you read the whole thing, and come up with a clear plan for how you'll write the code.
#
# Roulette is a betting game. There are 37 possible outcomes: A green 0, and the numbers 1 to 36 in red and black. Here is a picture of the (American, not Euro, it has an extra green 00) betting board:
#
# ![Roulette](./src/euro_roulette.jpg)
#
# To bet, you must pay a dollar, but then you get payouts that depend on how many slots are in your bet
# - Basic bets:
#     - Red or Black slots
#     - Odd or Even slots
#     - A single slots, like 20
# - More complex bets:
#     - Split: Two adjacent slots (e.g. {1,2})
#     - Square: Four adjacent slots (e.g. {1,2,4,5})
#     - Street: Three slots in a row (e.g. {1,2,3})
#     - Line: Six slots (e.g. {1,2,3,4,5,6})
# In general, you can only bet on 1, 2, 3, 4, 6 slots, 12 slots, or 18 slots. If your bet occurs when the wheel is spun, you gain 36/K-1 where $K$ is the number of slots you bet on; if not, you lose a dollar and get -1.
#
# - Write code to model spinning the roulette wheel, including the colors and numbers (you could make two lists of number and color and draw a random number between 0 and 37... or use a dataframe with color and number variables and sample it... or use a dict with key to number/color pairs...)
# - Describe the probability space associated with the roulette wheel: Outcomes, events, probabilities (If there are 37 outcomes, there are $2^{37}= 137,438,953,472$ events, by the way)
# - You wrote code to generate a spin of the roulette wheel. Now write a function that takes a basic or complex bet as an argument, and returns the result for the player (win or lose, and the payout 36/K-1 or -1)
# - Simulate betting on red, betting on odd, betting on 7, a split, and a line 1000 times each.
# - Compute the average values for the bets you just simulated. What are the expected average payoffs?

# %%
import random
import numpy as np

class Roulette:
    def __init__(self):
        self.slots = []
        
        self.slots.append({'number': 0, 'color': 'green'})
        
        red_numbers = [1, 3, 5, 7, 9, 12, 14, 16, 18, 19, 21, 23, 25, 27, 30, 32, 34, 36]
        
        for number in range(1, 37):
            color = 'red' if number in red_numbers else 'black'
            self.slots.append({'number': number, 'color': color})
    
    def spin(self):
        """Spin the wheel and return a random outcome"""
        return random.choice(self.slots)
    
    def calculate_payout(self, bet_slots, outcome):
        """
        Calculate payout for a bet
        bet_slots: list of numbers being bet on
        outcome: the actual outcome from spin()
        Returns: payout amount
        """
        K = len(bet_slots)
        if outcome['number'] in bet_slots:
            return (36 / K) - 1
        else:
            return -1

def define_bets():
    """Define common bet types"""
    bets = {
        'red': [num for num in range(1, 37) if 
                num in [1, 3, 5, 7, 9, 12, 14, 16, 18, 19, 21, 23, 25, 27, 30, 32, 34, 36]],
        
        'black': [num for num in range(1, 37) if 
                  num in [2, 4, 6, 8, 10, 11, 13, 15, 17, 20, 22, 24, 26, 28, 29, 31, 33, 35]],
        
        'odd': [num for num in range(1, 37) if num % 2 == 1],
        
        'even': [num for num in range(1, 37) if num % 2 == 0],
        
        'single_7': [7],
        
        'split_1_2': [1, 2],
        
        'line_1_6': [1, 2, 3, 4, 5, 6]
    }
    return bets

def simulate_bet(roulette, bet_slots, num_simulations=1000):
    """Simulate a bet multiple times and return results"""
    payouts = []
    wins = 0
    
    for _ in range(num_simulations):
        outcome = roulette.spin()
        payout = roulette.calculate_payout(bet_slots, outcome)
        payouts.append(payout)
        
        if payout > -1:
            wins += 1
    
    avg_payout = sum(payouts) / len(payouts)
    win_rate = wins / num_simulations
    
    return payouts, avg_payout, win_rate

def main():
    roulette = Roulette()
    
    bets = define_bets()
    
    print("=== ROULETTE PROBABILITY SPACE ===")
    print(f"Total outcomes: {len(roulette.slots)}")
    print("Outcomes: 0 (green), 1-36 (red/black)")
    print(f"Total possible events: 2^{len(roulette.slots)} = {2**len(roulette.slots):,}")
    print(f"Probability of any single number: {1/len(roulette.slots):.4f}")
    print()
    
    num_simulations = 1000
    results = {}
    
    print("=== BET SIMULATION RESULTS (1000 spins each) ===")
    print(f"{'Bet Type':<15} {'Avg Payout':<12} {'Win Rate':<10} {'K (slots)':<10}")
    print("-" * 50)
    
    for bet_name, bet_slots in bets.items():
        payouts, avg_payout, win_rate = simulate_bet(roulette, bet_slots, num_simulations)
        results[bet_name] = {
            'avg_payout': avg_payout,
            'win_rate': win_rate,
            'K': len(bet_slots)
        }
        
        print(f"{bet_name:<15} {avg_payout:<12.4f} {win_rate:<10.4f} {len(bet_slots):<10}")
    
    print("\n=== EXPECTED VALUE ANALYSIS ===")
    print("Theoretical expected values:")
    
    for bet_name, bet_info in results.items():
        K = bet_info['K']
        p_win = K / 37
        p_lose = 1 - p_win
        
        theoretical_ev = p_win * ((36/K) - 1) + p_lose * (-1)
        theoretical_ev_simplified = -1/37
        
        print(f"{bet_name:<15}: {theoretical_ev:.6f} (theoretical EV per $1 bet)")
    
    print(f"\nAll bets have the same theoretical EV: -1/37 ≈ {-1/37:.6f}")
    print("This represents the house edge in European roulette.")

if __name__ == "__main__":
    main()
# Out:
# === ROULETTE PROBABILITY SPACE ===
# Total outcomes: 37
# Outcomes: 0 (green), 1-36 (red/black)
# Total possible events: 2^37 = 137,438,953,472
# Probability of any single number: 0.0270
#
# === BET SIMULATION RESULTS (1000 spins each) ===
# Bet Type        Avg Payout   Win Rate   K (slots)
# --------------------------------------------------
# red             -0.0760      0.4620     18
# black           -0.0180      0.4910     18
# odd             -0.0320      0.4840     18
# even            -0.0380      0.4810     18
# single_7        -0.0640      0.0260     1
# split_1_2       0.0440       0.0580     2
# line_1_6        0.0440       0.1740     6
#
# === EXPECTED VALUE ANALYSIS ===
# Theoretical expected values:
# red            : -0.027027 (theoretical EV per $1 bet)
# black          : -0.027027 (theoretical EV per $1 bet)
# odd            : -0.027027 (theoretical EV per $1 bet)
# even           : -0.027027 (theoretical EV per $1 bet)
# ...

# %% [markdown]
# ### 5. CDF and PDF Basics
#
# - Verify the following functions are distribution functions and compute their density functions. Plot the distribution and density.
#
# 1. $F(x) = \begin{cases}
# 0, & x \le 0 \\
# \sqrt{x}, & 0 \le x \le 1 \\
# 1, & x \ge 1
# \end{cases}
# $
# 2. $F(x) = \dfrac{1}{1+e^{-x}}$
# 3. For $ a < b < c$,
# $
# F(x) = \begin{cases}
# 0, & x \le 0 \\
# \frac{(x-a)^2}{(b-a)(b-c)}, & a \le x \le c \\
# 1 - \frac{(b-x)^2}{(b-a)(b-c)}, & c < x < b \\
# 1, & x \ge b
# \end{cases}
# $
# 4. $ F(x) = \begin{cases}
# 0, & x <0 \\
# 1 - e^{-x}, & x>0
# \end{cases}
# $
# 5. $ F(x) = \begin{cases}
# 0, & x \le 0 \\
# x, & 0 < x < 1\\
# 1, & x \ge 1
# \end{cases}
# $

# %% [markdown]
# ### 6. Some Common Distributions
#
# For the following distributions:
# - Determine the support
# - Compute the density from the distribution for the logistic and exponential distributions (take a derivative)
# - Plot the density and distribution for a variety of parameter values
# - Take a sample of 1000 draws $(x_1, x_2, ..., x_{1000})$ from the distribution, plot a KDE and ECDF, visually compare with the theoretical pdf/cdf
# - Find an example of this general type of PDF/CDF from the Metabric cancer data
#
# You can use https://docs.scipy.org/doc/scipy/reference/stats.html to generate values for the pdf/cdf and generate samples of random variates.
#
#
# - Logistic distribution (similar to normal):
# $$
# F(x; \sigma) = \dfrac{1}{1+e^{-x/\sigma}}
# $$
# with $\sigma >0$.
# - Exponential distribution (similar to log-normal):
# $$
# F_X(x) = \begin{cases}
# 0, & x<0 \\
# 1 - e^{-\lambda x}, & x \ge 0,
# \end{cases}
# $$
# with $\lambda > 0$.
# - Negative Binomial (similar to Poisson): The probability mass function for positive integers is:
# $$
# f(k;r,p) = \dfrac{(k+r-1)!}{k!(r-1)!}(1-p)^k p^r, \quad \text{ for $k=0,...n$}
# $$
# You can interpret this as follows: Flip a coin that comes up heads with probability $p$ until you get $r$ heads, and then stop. What is the probability of stopping at each $k=0,1,2,...$?
# - Categorical (similar to Bernoulli): The probability mass function over $k = 1, 2, ..., K$ categories is
# $$
# f(k;p_1,...,p_K) = p_1^{k=1}p_2^{k=2}...p_K^{k=K}
# $$
# where $0 \le p_i \le 1$ and $ \sum_{k=1}^K p_k = 1$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.special import comb
import seaborn as sns

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print("=== LOGISTIC DISTRIBUTION ===")
print("Support: All real numbers (-∞, ∞)")

def logistic_pdf(x, sigma):
    """Compute PDF of logistic distribution by taking derivative of CDF"""
    exp_term = np.exp(-x/sigma)
    return (1/sigma) * exp_term / ((1 + exp_term)**2)

sigma_values = [0.5, 1, 2]
x_range = np.linspace(-8, 8, 1000)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

for sigma in sigma_values:
    logistic_dist = stats.logistic(scale=sigma)
    
    ax1.plot(x_range, logistic_pdf(x_range, sigma), 
             label=f'σ={sigma}', linewidth=2)
    
    ax2.plot(x_range, logistic_dist.cdf(x_range), 
             label=f'σ={sigma}', linewidth=2)

ax1.set_title('Logistic Distribution - PDF')
ax1.set_xlabel('x')
ax1.set_ylabel('f(x)')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_title('Logistic Distribution - CDF')
ax2.set_xlabel('x')
ax2.set_ylabel('F(x)')
ax2.legend()
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
sigma = 1
samples = stats.logistic(scale=sigma).rvs(1000)

ax1.hist(samples, bins=30, density=True, alpha=0.5, label='Histogram')
sns.kdeplot(samples, ax=ax1, label='KDE')
ax1.plot(x_range, logistic_pdf(x_range, sigma), 'r-', linewidth=2, label='Theoretical PDF')
ax1.set_title('PDF Comparison')
ax1.legend()

from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(samples)
ax2.step(ecdf.x, ecdf.y, where='post', label='ECDF')
ax2.plot(x_range, stats.logistic(scale=sigma).cdf(x_range), 'r-', 
         linewidth=2, label='Theoretical CDF')
ax2.set_title('CDF Comparison')
ax2.legend()

plt.tight_layout()
plt.show()

print("\n=== EXPONENTIAL DISTRIBUTION ===")
print("Support: [0, ∞)")

def exponential_pdf(x, lam):
    """Compute PDF of exponential distribution by taking derivative of CDF"""
    return lam * np.exp(-lam * x) * (x >= 0)

lambda_values = [0.5, 1, 2]
x_range_exp = np.linspace(0, 8, 1000)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

for lam in lambda_values:
    exp_dist = stats.expon(scale=1/lam)
    
    ax1.plot(x_range_exp, exponential_pdf(x_range_exp, lam), 
             label=f'λ={lam}', linewidth=2)
    
    ax2.plot(x_range_exp, exp_dist.cdf(x_range_exp), 
             label=f'λ={lam}', linewidth=2)

ax1.set_title('Exponential Distribution - PDF')
ax1.set_xlabel('x')
ax1.set_ylabel('f(x)')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_title('Exponential Distribution - CDF')
ax2.set_xlabel('x')
ax2.set_ylabel('F(x)')
ax2.legend()
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
lam = 1
samples_exp = stats.expon(scale=1/lam).rvs(1000)

ax1.hist(samples_exp, bins=30, density=True, alpha=0.5, label='Histogram')
sns.kdeplot(samples_exp, ax=ax1, label='KDE')
ax1.plot(x_range_exp, exponential_pdf(x_range_exp, lam), 'r-', 
         linewidth=2, label='Theoretical PDF')
ax1.set_title('PDF Comparison')
ax1.legend()

ecdf_exp = ECDF(samples_exp)
ax2.step(ecdf_exp.x, ecdf_exp.y, where='post', label='ECDF')
ax2.plot(x_range_exp, stats.expon(scale=1/lam).cdf(x_range_exp), 'r-', 
         linewidth=2, label='Theoretical CDF')
ax2.set_title('CDF Comparison')
ax2.legend()

plt.tight_layout()
plt.show()

print("\n=== NEGATIVE BINOMIAL DISTRIBUTION ===")
print("Support: Non-negative integers {0, 1, 2, ...}")

def negative_binomial_pmf(k, r, p):
    """PMF of negative binomial distribution"""
    return comb(k + r - 1, k) * (1 - p)**k * p**r

r_values = [2, 5, 10]
p_values = [0.3, 0.5, 0.7]
k_range = np.arange(0, 30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, (r, p) in enumerate(zip(r_values, p_values)):
    pmf_values = [negative_binomial_pmf(k, r, p) for k in k_range]
    axes[i].bar(k_range, pmf_values, alpha=0.7)
    axes[i].set_title(f'Negative Binomial PMF (r={r}, p={p})')
    axes[i].set_xlabel('k')
    axes[i].set_ylabel('P(X=k)')
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
r, p = 5, 0.4
samples_nb = stats.nbinom(r, p).rvs(1000)

ax1.hist(samples_nb, bins=30, density=True, alpha=0.7, label='Histogram')
k_max = int(np.max(samples_nb))
k_vals = np.arange(0, k_max + 1)
pmf_vals = [negative_binomial_pmf(k, r, p) for k in k_vals]
ax1.plot(k_vals, pmf_vals, 'ro-', label='Theoretical PMF')
ax1.set_title('PMF Comparison')
ax1.legend()

ecdf_nb = ECDF(samples_nb)
x_cdf = np.linspace(0, np.max(samples_nb), 1000)
ax2.step(ecdf_nb.x, ecdf_nb.y, where='post', label='ECDF')
ax2.plot(x_cdf, stats.nbinom(r, p).cdf(x_cdf), 'r-', 
         linewidth=2, label='Theoretical CDF')
ax2.set_title('CDF Comparison')
ax2.legend()

plt.tight_layout()
plt.show()

print("\n=== CATEGORICAL DISTRIBUTION ===")
print("Support: Categories {1, 2, ..., K}")

def categorical_pmf(k, probs):
    """PMF of categorical distribution"""
    return probs[k-1] if 1 <= k <= len(probs) else 0

prob_sets = [
    [0.2, 0.3, 0.5],
    [0.1, 0.1, 0.3, 0.5],
    [0.25, 0.25, 0.25, 0.25] 
]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, probs in enumerate(prob_sets):
    categories = np.arange(1, len(probs) + 1)
    axes[i].bar(categories, probs, alpha=0.7)
    axes[i].set_title(f'Categorical PMF (K={len(probs)})')
    axes[i].set_xlabel('Category')
    axes[i].set_ylabel('Probability')
    axes[i].set_xticks(categories)
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
probs = [0.2, 0.3, 0.5]
categories = np.arange(1, len(probs) + 1)

samples_cat = np.random.choice(categories, size=1000, p=probs)

ax1.hist(samples_cat, bins=len(probs), density=True, alpha=0.7, 
         label='Histogram', rwidth=0.8)
ax1.bar(categories, probs, alpha=0.5, label='Theoretical PMF', 
        width=0.4, color='red')
ax1.set_title('PMF Comparison')
ax1.set_xlabel('Category')
ax1.set_ylabel('Probability')
ax1.legend()
ax1.set_xticks(categories)

ecdf_cat = ECDF(samples_cat)
x_cat = np.linspace(0.5, len(probs) + 0.5, 1000)
cdf_vals = [sum(probs[:int(x)]) if x <= len(probs) else 1 for x in x_cat]

ax2.step(ecdf_cat.x, ecdf_cat.y, where='post', label='ECDF')
ax2.plot(x_cat, cdf_vals, 'r-', linewidth=2, label='Theoretical CDF')
ax2.set_title('CDF Comparison')
ax2.set_xlabel('Category')
ax2.set_ylabel('Cumulative Probability')
ax2.legend()

plt.tight_layout()
plt.show()

print("\n=== SUMMARY ===")
print("Logistic Distribution:")
print(f"  Support: All real numbers")
print(f"  PDF derived: f(x;σ) = (1/σ) * e^(-x/σ) / (1 + e^(-x/σ))²")

print("\nExponential Distribution:")
print(f"  Support: [0, ∞)")
print(f"  PDF derived: f(x;λ) = λe^(-λx) for x ≥ 0")

print("\nNegative Binomial Distribution:")
print(f"  Support: Non-negative integers")
print(f"  PMF: P(X=k) = C(k+r-1, k) * (1-p)^k * p^r")

print("\nCategorical Distribution:")
print(f"  Support: Categories {{1, 2, ..., K}}")
print(f"  PMF: P(X=k) = p_k for k = 1,...,K")
# Out:
# === LOGISTIC DISTRIBUTION ===
# Support: All real numbers (-∞, ∞)
# === EXPONENTIAL DISTRIBUTION ===
# Support: [0, ∞)
# === NEGATIVE BINOMIAL DISTRIBUTION ===
# Support: Non-negative integers {0, 1, 2, ...}
# === CATEGORICAL DISTRIBUTION ===
# Support: Categories {1, 2, ..., K}
# === SUMMARY ===
# Logistic Distribution:
#   Support: All real numbers
#   PDF derived: f(x;σ) = (1/σ) * e^(-x/σ) / (1 + e^(-x/σ))²
#
# Exponential Distribution:
#   Support: [0, ∞)
#   PDF derived: f(x;λ) = λe^(-λx) for x ≥ 0
#
# Negative Binomial Distribution:
#   Support: Non-negative integers
#   PMF: P(X=k) = C(k+r-1, k) * (1-p)^k * p^r
#
# Categorical Distribution:
#   Support: Categories {1, 2, ..., K}
#   PMF: P(X=k) = p_k for k = 1,...,K
